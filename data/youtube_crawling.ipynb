# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas
from googleapiclient.discovery import build

import warnings
warnings.filterwarnings('ignore')

developer_key = 'AIzaSyDVwQXiuQHIQIw6JZGKwLVK1A0E0HEprEg'
videoID = 'eF7kk4KE5BA'

comments = list()
api_obj = build('youtube', 'v3', developerKey=developer_key)
response = api_obj.commentThreads().list(part='snippet', videoId=videoID, maxResults = 100).execute()

while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])

    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet', videoId=videoID, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

df=pandas.DataFrame(comments, columns=['Comment', 'ID', 'Time', 'Like'])

# %%
df
# Out:
#                                              Comment        ID  \
# 0                           이새끼는 근본이 안되어있어<br>범죄자 새끼       하이요
# 1                                          저질<br>ㅋㅋㅋ       성우배
# 2                                           개극혐이다 진짜    SNOOZE
# 3                                          토할 것 같다..         ㅇ
# 4    승리 비판 전혀 상관없이 , 저 댓글들만 보여주는게 과연 sbs수준을 올릴까 내릴까?         B
# ..                                               ...       ...
# 472                             ㅋㅋㅋㅋㅋㅋㅋ 행복 그자체네 범죄자가        ᄏᄏ
# 473                                     아직 어려서 그래요~~     요.봉아빠
# 474                                          여윽시 또라이  융DUCTIST
# 475                                         본성은 안변한다    hm kim
# 476                                   ㅋㅋㅋㅋ 살기좋은 우리나라       쌈무.
#
#                      Time  Like
# 0    2023-05-31T23:32:47Z     0
# 1    2023-05-31T15:20:44Z     0
# 2    2023-05-29T00:30:59Z     0
# 3    2023-05-27T13:45:47Z     0
# 4    2023-05-26T01:42:48Z     0
# ...

# %%
df=df[['Comment']]

# %%
df.columns=['댓글']

# %%
df['댓글'] = df['댓글'].str.replace('<br>', '', regex=False)

# %%
df
# Out:
#                                                   댓글
# 0                               이새끼는 근본이 안되어있어범죄자 새끼
# 1                                              저질ㅋㅋㅋ
# 2                                           개극혐이다 진짜
# 3                                          토할 것 같다..
# 4    승리 비판 전혀 상관없이 , 저 댓글들만 보여주는게 과연 sbs수준을 올릴까 내릴까?
# ..                                               ...
# 472                             ㅋㅋㅋㅋㅋㅋㅋ 행복 그자체네 범죄자가
# 473                                     아직 어려서 그래요~~
# 474                                          여윽시 또라이
# 475                                         본성은 안변한다
# 476                                   ㅋㅋㅋㅋ 살기좋은 우리나라
#
# [477 rows x 1 columns]

# %%
df.to_csv("댓글.csv",encoding='utf-8-sig', index=False)
